# %% [markdown]
# # Secret Scan\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom ai_coding.secrets import findings\nprint(findings("password = \"demo-secret\""))
