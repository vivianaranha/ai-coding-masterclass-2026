# %% [markdown]
# # Workflow Evaluation\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom ai_coding.eval import workflow_score\nprint(workflow_score(1,.9,1,.8))
