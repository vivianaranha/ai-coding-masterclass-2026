# %% [markdown]
# # Spec Completeness\n\n**Created by School of AI**

# %%
import sys\nfrom pathlib import Path\nsys.path.append(str(Path.cwd().parent/"src"))\nfrom ai_coding.specs import completeness\nprint(completeness({"goal":"x","acceptance":["test"],"constraints":["local"],"tests":["unit"]}))
